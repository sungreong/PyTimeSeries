# %%
import sys
sys.path.append("./../")
from src.preprocessing.utils import make_lower_column
import yfinance as yf
# Request historical data for past 5 years
data = yf.Ticker("^GSPC").history(period='5y')
data.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2017-03-03  2380.919922  2383.889893  2375.389893  2383.120117  3555260000
# 2017-03-06  2375.229980  2378.800049  2367.979980  2375.310059  3232700000
# 2017-03-07  2370.739990  2375.120117  2365.510010  2368.389893  3518390000
# 2017-03-08  2369.810059  2373.090088  2361.010010  2362.979980  3812100000
# 2017-03-09  2363.489990  2369.080078  2354.540039  2364.870117  3716340000
#
#             Dividends  Stock Splits
# Date
# 2017-03-03          0             0
# 2017-03-06          0             0
# 2017-03-07          0             0
# 2017-03-08          0             0
# 2017-03-09          0             0

# %%
import yfinance as yf
data = yf.download("^GSPC", start='2019-01-01', end='2022-02-21')
data = make_lower_column(data.reset_index(drop=False))
data.columns = [i.replace(" ", "_") for i in list(data)]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib
data = yf.download("^GSPC", start='2019-01-01', end='2021-01-01')
data.plot(y="Close")




data = yf.download("^GSPC", start='2021-01-01', end='2022-01-01')
data.plot(y="Close")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <AxesSubplot:xlabel='Date'>

# %%
from src.preprocessing.utils import make_lower_column

# %%
data = make_lower_column(data)
data.head()
# Out:
#                    open         high          low        close    adj close  \
# Date
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
# 2021-01-04  3764.610107  3769.989990  3662.709961  3700.649902  3700.649902
# 2021-01-05  3698.020020  3737.830078  3695.070068  3726.860107  3726.860107
# 2021-01-06  3712.199951  3783.040039  3705.340088  3748.139893  3748.139893
# 2021-01-07  3764.709961  3811.550049  3764.709961  3803.790039  3803.790039
#
#                 volume
# Date
# 2020-12-31  3172510000
# 2021-01-04  5006680000
# 2021-01-05  4582620000
# 2021-01-06  6049970000
# 2021-01-07  5080870000

# %%
import sys
sys.path.append("./..")

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.preprocessing.utils import make_lower_column
from src.preprocessing.stock_preprocessing import process_ma_ratio

# %%
data = make_lower_column(data)
process_ma_ratio(data)
# Out:
# make new cols
# ['close_ma5_ratio', 'close_ma10_ratio', 'close_ma20_ratio', 'close_ma60_ratio', 'close_ma120_ratio', 'volume_ma5_ratio', 'volume_ma10_ratio', 'volume_ma20_ratio', 'volume_ma60_ratio', 'volume_ma120_ratio']
#                    open         high          low        close    adj close  \
# Date
# 2021-06-23  4249.270020  4256.600098  4241.430176  4241.839844  4241.839844
# 2021-06-24  4256.970215  4271.279785  4256.970215  4266.490234  4266.490234
# 2021-06-25  4274.450195  4286.120117  4271.160156  4280.700195  4280.700195
# 2021-06-28  4284.899902  4292.140137  4274.669922  4290.609863  4290.609863
# 2021-06-29  4293.209961  4300.520020  4287.040039  4291.799805  4291.799805
# ...                 ...          ...          ...          ...          ...
# 2021-12-27  4733.990234  4791.490234  4733.990234  4791.189941  4791.189941
# 2021-12-28  4795.490234  4807.020020  4780.040039  4786.350098  4786.350098
# ...
